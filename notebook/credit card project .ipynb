# %% [markdown]
# # Problem Statement
# A credit card is one of the most used financial products to make online purchases and payments. Though the Credit cards can be a convenient way to manage your finances, they can also be risky. Credit card fraud is the unauthorized use of someone else's credit card or credit card information to make purchases or withdraw cash.
# It is important that credit card companies are able to recognize fraudulent credit card transactions so that customers are not charged for items that they did not purchase.
# The dataset contains transactions made by credit cards in September 2013 by European cardholders. This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.
# We have to build a classification model to predict whether a transaction is fraudulent or not.

# %% [markdown]
# # Table of Content
#
# 1. **[Import Libraries](#lib)**
# 2. **[Data Preparation](#prep)**
#     - 2.1 - **[Understand the Data](#read)**
#     - 2.2 - **[Exploratory Data Analysis](#eda)**
#     - 2.3 - **[Missing Value Treatment](#null)**
#     - 2.4 - **[Outliers Treatment](#outlier)**
#     - 2.5 - **[Encoding and Feature Scaling](#enc)**
#     - 2.6 - **[Feature Selection](#feat_sl)**
#     - 2.7 - **[Handling Imbalance Data](#imbalance)**
# 3. **[SCORE CARD](#scorecard)**
# 4. **[Splitting the data into Train and Test](#sd)**
# 5. **[Modelling](#model)**
#     - 5.1 - **[Logistic Regression Model](#log_model)**
#         - 5.1.1 - **[Model Evaluation](#eval)**
#         - 5.1.2 - **[AUC ROC Curve](#ar_curve)**
#         - 5.1.3 - **[Hyperparameter Tuning](#hyp_tune)**
#         - 5.1.4 - **[Model Evaluation(Tuned model)](#eval_tune)**
#         - 5.1.5 - **[AUC ROC Curve(Tuned Model)](#ar_curve_tune)**
#         - 5.1.6 - **[Model Validation](#model_val)**
#         - 5.1.7 **[Feature Importance](#feat_imp_log)**
#         - 5.1.8 **[Confusion Matrix](#conf_mat_log)**
#     - 5.2 - **[Random Forest CLassifier Model](#rfc_model)**
#         - 5.2.1 - **[Model Evaluation](#eval_rf)**
#         - 5.2.2 - **[AUC ROC Curve](#ar_curve_rf)**
#         - 5.2.3 - **[Hyperparameter Tuning](#hyp_tune_rf)**
#         - 5.2.4 - **[Model Evaluation(Tuned model)](#eval_tune_rf)**
#         - 5.2.5 - **[AUC ROC Curve(Tuned Model)](#ar_curve_tune_rf)**
#         - 5.2.6 - **[Model Validation](#model_val_rf)**
#         - 5.2.7 **[Feature Importance](#feat_imp_rf)**
#         - 5.2.8 **[Confusion Matrix](#conf_mat_rf)**
#     - 5.3 - **[Decision Tree CLassifier Model](#dtc_model)**
#         - 5.3.1 - **[Model Evaluation](#eval_dt)**
#         - 5.3.2 - **[AUC ROC Curve](#ar_curve_dt)**
#         - 5.3.3 - **[Hyperparameter Tuning](#hyp_tune_dt)**
#         - 5.3.4 - **[Model Evaluation(Tuned model)](#eval_tune_dt)**
#         - 5.3.5 - **[AUC ROC Curve(Tuned Model)](#ar_curve_tune_dt)**
#         - 5.3.6 - **[Model Validation](#model_val_dt)**
#         - 5.3.7 **[Feature Importance](#feat_imp_dt)**
#         - 5.3.8 **[Confusion Matrix](#conf_mat_dt)**
#     - 5.4 - **[SVM Model](#svm_model)**
#         - 5.4.1 - **[Model Evaluation](#eval_svm)**
#         - 5.4.2 - **[AUC ROC Curve](#ar_curve_svm)**
#         - 5.4.3 - **[Hyperparameter Tuning](#hyp_tune_svm)**
#         - 5.4.4 - **[Model Evaluation(Tuned model)](#eval_tune_svm)**
#         - 5.4.5 - **[AUC ROC Curve(Tuned Model)](#ar_curve_tune_svm)**
#         - 5.4.6 - **[Model Validation](#model_val_svm)**
#         - 5.4.7 **[Feature Importance](#feat_imp_svm)**
#         - 5.4.8 **[Confusion Matrix](#conf_mat_svm)**
#     - 5.5 - **[Gradient Boosting CLassifier Model](#gbm_model)**
#         - 5.5.1 - **[Model Evaluation](#eval_gbm)**
#         - 5.5.2 - **[AUC ROC Curve](#ar_curve_gbm)**
#         - 5.5.3 - **[Hyperparameter Tuning](#hyp_tune_gbm)**
#         - 5.5.4 - **[Model Evaluation(Tuned model)](#eval_tune_gbm)**
#         - 5.5.5 - **[AUC ROC Curve(Tuned Model)](#ar_curve_tune_gbm)**
#         - 5.5.6 - **[Model Validation](#model_val_gbm)**
#         - 5.5.7 **[Feature Importance](#feat_imp_gbm)**
#         - 5.5.8 **[Confusion Matrix](#conf_mat_gbm)**
#     - 5.6 - **[XGBoost Model](#xgb_model)**
#         - 5.6.1 - **[Model Evaluation](#eval_xgb)**
#         - 5.6.2 - **[AUC ROC Curve](#ar_curve_xgb)**
#         - 5.6.3 - **[Hyperparameter Tuning](#hyp_tune_xgb)**
#         - 5.6.4 - **[Model Evaluation(Tuned model)](#eval_tune_xgb)**
#         - 5.6.5 - **[AUC ROC Curve(Tuned Model)](#ar_curve_tune_xgb)**
#         - 5.6.6 - **[Model Validation](#model_val_xgb)**
#         - 5.6.7 **[Feature Importance](#feat_imp_xgb)**
#         - 5.6.8 **[Confusion Matrix](#conf_mat_xgb)**
#     - 5.7 - **[Decision Tree CLassifier Model](#lgbm_model)**
#         - 5.7.1 - **[Model Evaluation](#eval_lgbm)**
#         - 5.7.2 - **[AUC ROC Curve](#ar_curve_lgbm)**
#         - 5.7.3 - **[Hyperparameter Tuning](#hyp_tune_lgbm)**
#         - 5.7.4 - **[Model Evaluation(Tuned model)](#eval_tune_lgbm)**
#         - 5.7.5 - **[AUC ROC Curve(Tuned Model)](#ar_curve_tune_lgbm)**
#         - 5.7.6 - **[Model Validation](#model_val_lgbm)**
#         - 5.7.7 **[Feature Importance](#feat_imp_lgbm)**
#         - 5.7.8 **[Confusion Matrix](#conf_mat_lgbm)**
# 6. **[FINAL SCORECARD](#final_score)**

# %% [markdown]
# <a id=lib></a>
# # 1. Import Libraries

# %%
#Importing the basic python libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 

#Importing scikit-learn libraries 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# <a id='prep'></a>
# # 2. Data Preparation

# %%
df = pd.read_csv(r'C:\Users\dell\FINAL_CAPSTONE_PROJECT\find-default-prediction-of-credit-card-fraud)\dataset(s)\credit card.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# <a id='read'></a>
# ## 2.1 - Understand the Data

# %%
#The info command will help us to understand the different columns present in the dataset and its datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
#Len command will help us understand the total number of records present in the dataset
len(df)
# Out:
# 284807

# %%
# getting shape of dataset i.e, number of rows and columns using .shape command
df.shape
# Out:
# (284807, 31)

# %%
#.columns command will help us understand the columns present in the dataset
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
# using .describe command to check descriptive statistics
np.round(df.describe(),4)
# Out:
#               Time           V1           V2           V3           V4  \
# count  284807.0000  284807.0000  284807.0000  284807.0000  284807.0000
# mean    94813.8596       0.0000      -0.0000      -0.0000       0.0000
# std     47488.1460       1.9587       1.6513       1.5163       1.4159
# min         0.0000     -56.4075     -72.7157     -48.3256      -5.6832
# 25%     54201.5000      -0.9204      -0.5985      -0.8904      -0.8486
# 50%     84692.0000       0.0181       0.0655       0.1798      -0.0198
# 75%    139320.5000       1.3156       0.8037       1.0272       0.7433
# max    172792.0000       2.4549      22.0577       9.3826      16.8753
#
#                 V5           V6           V7           V8           V9  ...  \
# count  284807.0000  284807.0000  284807.0000  284807.0000  284807.0000  ...
# mean        0.0000       0.0000      -0.0000       0.0000      -0.0000  ...
# std         1.3802       1.3323       1.2371       1.1944       1.0986  ...
# min      -113.7433     -26.1605     -43.5572     -73.2167     -13.4341  ...
# 25%        -0.6916      -0.7683      -0.5541      -0.2086      -0.6431  ...
# 50%        -0.0543      -0.2742       0.0401       0.0224      -0.0514  ...
# 75%         0.6119       0.3986       0.5704       0.3273       0.5971  ...
# max        34.8017      73.3016     120.5895      20.0072      15.5950  ...
#
#                V21          V22          V23          V24          V25  \
# count  284807.0000  284807.0000  284807.0000  284807.0000  284807.0000
# mean       -0.0000      -0.0000      -0.0000       0.0000      -0.0000
# std         0.7345       0.7257       0.6245       0.6056       0.5213
# min       -34.8304     -10.9331     -44.8077      -2.8366     -10.2954
# 25%        -0.2284      -0.5424      -0.1618      -0.3546      -0.3171
# 50%        -0.0295       0.0068      -0.0112       0.0410       0.0166
# 75%         0.1864       0.5286       0.1476       0.4395       0.3507
# max        27.2028      10.5031      22.5284       4.5845       7.5196
#
#                V26          V27          V28       Amount        Class
# count  284807.0000  284807.0000  284807.0000  284807.0000  284807.0000
# mean       -0.0000       0.0000      -0.0000      88.3496       0.0017
# std         0.4822       0.4036       0.3301     250.1201       0.0415
# min        -2.6046     -22.5657     -15.4301       0.0000       0.0000
# 25%        -0.3270      -0.0708      -0.0530       5.6000       0.0000
# 50%        -0.0521       0.0013       0.0112      22.0000       0.0000
# 75%         0.2410       0.0910       0.0783      77.1650       0.0000
# max         3.5173      31.6122      33.8478   25691.1600       1.0000
#
# [8 rows x 31 columns]

# %%
df.skew()
# Out:
# Time      -0.035568
# V1        -3.280667
# V2        -4.624866
# V3        -2.240155
# V4         0.676292
# V5        -2.425901
# V6         1.826581
# V7         2.553907
# V8        -8.521944
# V9         0.554680
# V10        1.187141
# V11        0.356506
# V12       -2.278401
# V13        0.065233
# V14       -1.995176
# V15       -0.308423
# V16       -1.100966
# V17       -3.844914
# V18       -0.259880
# V19        0.109192
# V20       -2.037155
# V21        3.592991
# V22       -0.213258
# V23       -5.875140
# V24       -0.552499
# V25       -0.415793
# V26        0.576693
# V27       -1.170209
# V28       11.192091
# Amount    16.977724
# Class     23.997579
# dtype: float64

# %%
df.kurt()
# Out:
# Time       -1.293530
# V1         32.486679
# V2         95.773106
# V3         26.619551
# V4          2.635455
# V5        206.904560
# V6         42.642494
# V7        405.607417
# V8        220.586974
# V9          3.731311
# V10        31.988239
# V11         1.633921
# V12        20.241870
# V13         0.195300
# V14        23.879462
# V15         0.284769
# V16        10.419131
# V17        94.799719
# V18         2.578341
# V19         1.724970
# V20       271.016113
# V21       207.287040
# V22         2.832967
# V23       440.088659
# V24         0.618871
# V25         4.290412
# V26         0.919006
# V27       244.989241
# V28       933.397502
# Amount    845.092646
# Class     573.887843
# dtype: float64

# %%
# checking if duplicates values are there or not 
df.duplicated().sum()
# Out:
# 1081

# %%
# we can remove these duplicated values 
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (283726, 31)

# %% [markdown]
# <a id="eda"></a>
# ## 2.2. Exploratory Data Analysis

# %% [markdown]
# ### 1. checking the distribution of fraud/non-fraud transactions

# %%
plt.figure(figsize=(8,5))
sns.countplot(x=df['Class'], width=0.5)
plt.title('Distribution of Fraud(0) and Non-Fraudulent(1) transactions')
plt.ylabel('Count of Transactions')
plt.xlabel('Type of transaction')
plt.show()

# %% [markdown]
# **clearly we can see there are very less number of fraudulent transactions confirming of dataset being imbalance**

# %% [markdown]
# ### 2.checking descriptive stats for fraud and non-fraud transactions with respect to amount

# %%
# descriptive stats for non-fraudulent transactions
df[df['Class']==0]['Amount'].describe()
# Out:
# count    283253.000000
# mean         88.413575
# std         250.379023
# min           0.000000
# 25%           5.670000
# 50%          22.000000
# 75%          77.460000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
# descriptive stats for fraudulent transactions
df[df['Class']==1]['Amount'].describe()
# Out:
# count     473.000000
# mean      123.871860
# std       260.211041
# min         0.000000
# 25%         1.000000
# 50%         9.820000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# **Points to be noted from above stats information**
#
#     1. average amount of 51 is for non-fraud transactions and avg amount for 122 is for fraud transactions
#     2. difference between the max of fraud and non-fraud transactions is quite huge

# %% [markdown]
# ### 3.The plot of the Time feature for both non-fraudulent and fraudulent transactions will provide insights into when these transactions occur relative to the starting point of the dataset.

# %%
# Plot the distribution of 'Time'
fig, ax = plt.subplots(2,1, figsize=(12, 8))

sns.histplot(df[df['Class']==0]['Time'], bins=50, kde=True, ax=ax[0])
ax[0].set_title('Distribution of Time Feature')
ax[0].set_xlabel('Time (seconds from first transaction(non-fraudulent))')
ax[0].set_ylabel('Frequency')

sns.histplot(df[df['Class']==1]['Time'], bins=50, kde=True, ax=ax[1])
ax[1].set_title('Distribution of Time Feature')
ax[1].set_xlabel('Time (seconds from first transaction(fradulent))')
ax[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **we see transaction time for fraud transactions are almost evenly spread but for non_fraud transactions time is not evenly spread**

# %% [markdown]
# ### 4. plot for transaction amount

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x='Class', y='Amount', hue='Class')
plt.title('Transaction Amount for fraud/non_fraud transactions')
plt.ylabel('Amount')
plt.xlabel('Class')
plt.show()

# %% [markdown]
# **clearly non fraud transactions have more outliers than fraud transactions**

# %% [markdown]
# ### 5. plot for amount of transaction with time of transaction

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='Time', y=df[df['Class']==1]['Amount'])
plt.title('Transaction Time and Amount of fraudulent transactions')
plt.ylabel('Amount')
plt.xlabel('Time')
plt.show()

# %% [markdown]
# **we can see from the above scatterplot there are very few numbers of fraud transaction above 1000(Amount)**

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='Time', y=df[df['Class']==0]['Amount'])
plt.title('Transaction Time and Amount of non_fraudulent transactions')
plt.ylabel('Amount')
plt.xlabel('Time')
plt.show()

# %% [markdown]
# **we can see from the above scatterplot there are very few numbers of non_fraud transaction above 10000(Amount)**

# %% [markdown]
# ### 6. Correlation Plot

# %%
plt.figure(figsize=(12,12))
corr = df.corr()
sns.heatmap(corr, cmap='Blues', linewidth=1.0, xticklabels=corr.columns, yticklabels=corr.columns)
plt.title('Credit Card Transactions features correlation plot')
plt.show()

# %% [markdown]
# **As expected, there is no notable correlation between features V1-V28**

# %% [markdown]
# <a id="null"></a>
# ## 2.3. Missing Value Treatment

# %%
np.round(df.isna().sum()/len(df)*100,3)
# Out:
# Time      0.0
# V1        0.0
# V2        0.0
# V3        0.0
# V4        0.0
# V5        0.0
# V6        0.0
# V7        0.0
# V8        0.0
# V9        0.0
# V10       0.0
# V11       0.0
# V12       0.0
# V13       0.0
# V14       0.0
# V15       0.0
# V16       0.0
# V17       0.0
# V18       0.0
# V19       0.0
# V20       0.0
# V21       0.0
# V22       0.0
# V23       0.0
# V24       0.0
# V25       0.0
# V26       0.0
# V27       0.0
# V28       0.0
# Amount    0.0
# Class     0.0
# dtype: float64

# %% [markdown]
# **no missing values found**

# %% [markdown]
# <a id="outlier"></a>
# ## 2.4. Outliers Treatment

# %%
# checking the outliers for fraud and no fraud transactions separately because 
# What is considered an outlier for non-fraudulent transactions might be typical behavior for fraudulent transactions.
# Plotting boxplots for each feature by 'Class' column
features = [col for col in df.columns if col != 'Class']

# Define the number of rows and columns for the subplot grid
n_cols = 3
n_rows = int(np.ceil(len(features) / n_cols))

# Create a figure and a set of subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 4 * n_rows))
fig.tight_layout(pad=4.0)

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Plot each feature in a separate subplot
for idx, col in enumerate(features):
    sns.boxplot(x='Class', y=col, data=df, ax=axes[idx])
    axes[idx].set_title(f'Boxplot of {col} by Class')
    axes[idx].set_xlabel('Class (0:Non-Fraud, 1:Fraud)')
    axes[idx].set_ylabel(col)

# Remove any empty subplots if features don't fill the grid completely
for i in range(len(features), len(axes)):
    fig.delaxes(axes[i])

# Show the plot
plt.show()

# %% [markdown]
# ### Handling Outliers for non_fraudulent transactions

# %%
# capping all columns having non_fraudulent transactions except Class and Time 
for col in df.columns:
    if col not in ['Class','Time']:
        q1 = df[df['Class']==0][col].quantile(0.25)
        q3 = df[df['Class']==0][col].quantile(0.75)
        iqr = q3-q1
        upperlimit = q3 + 1.5*iqr
        lowerlimit = q1 - 1.5*iqr
        # Apply capping for non-fraudulent rows only
        df.loc[(df['Class']==0) & (df[col]>upperlimit), col] = upperlimit
        df.loc[(df['Class']==0) & (df[col]<lowerlimit), col] = lowerlimit

# %%
# checking again if outliers are capped 
features = [col for col in df.columns if col != 'Class']

# Define the number of rows and columns for the subplot grid
n_cols = 3
n_rows = int(np.ceil(len(features) / n_cols))

# Create a figure and a set of subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 4 * n_rows))
fig.tight_layout(pad=4.0)

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Plot each feature in a separate subplot
for idx, col in enumerate(features):
    sns.boxplot(x='Class', y=col, data=df, ax=axes[idx])
    axes[idx].set_title(f'Boxplot of {col} by Class')
    axes[idx].set_xlabel('Class (0:Non-Fraud, 1:Fraud)')
    axes[idx].set_ylabel(col)

# Remove any empty subplots if features don't fill the grid completely
for i in range(len(features), len(axes)):
    fig.delaxes(axes[i])

# Show the plot
plt.show()

# %% [markdown]
# **outliers are capped**

# %% [markdown]
# <a id="enc"></a>
# ## 2.5. Encoding and Feature Scaling

# %%
# feature scaling Amount column because rest columns are in standard format
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

df[['Amount','Time']] = sc.fit_transform(df[['Amount','Time']])

# %%
df.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 284802  1.642235 -4.258760  2.894627 -3.752308 -2.066656 -2.638382 -2.515373
# 284803  1.642257 -0.732789 -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804  1.642278  1.919565 -0.301254 -3.249640 -0.557828  2.562936  2.145508
# 284805  1.642278 -0.240440  0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  1.642362 -0.533413 -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 284802 -2.231910  1.124443  1.914428  ...  0.213454  0.111864  0.611318
# 284803  0.024330  0.294869  0.584800  ...  0.214205  0.924384  0.012463
# 284804 -0.296827  0.708417  0.432454  ...  0.232045  0.578229 -0.037501
# 284805 -0.686180  0.679145  0.392087  ...  0.265245  0.800049 -0.163298
# 284806  1.577006 -0.414650  0.486180  ...  0.261057  0.643078  0.376777
#
#              V24       V25       V26       V27       V28    Amount  Class
# 284802 -0.509348  1.352439  0.250034  0.332876  0.274113 -0.815894      0
# 284803 -1.016226 -0.606624 -0.395255  0.068472 -0.053527 -0.433168      0
# 284804  0.640134  0.265745 -0.087371  0.004455 -0.026561  0.253412      0
# 284805  0.123205 -0.569159  0.546668  0.108821  0.104533 -0.668826      0
# 284806  0.008797 -0.473649 -0.818267 -0.002415  0.013649  2.121868      0
#
# [5 rows x 31 columns]

# %% [markdown]
# <a id="feat_sl"></a>
# ## 2.6. Feature Selection

# %% [markdown]
# ### Using Correlation to check corrleation of all columns with target feature Class and removing less correlated features

# %%
corr = df.corr()

corr_with_class = corr.drop('Class')['Class']

corr_with_class
# Out:
# Time     -0.012359
# V1       -0.115477
# V2        0.120743
# V3       -0.194536
# V4        0.139169
# V5       -0.109604
# V6       -0.054580
# V7       -0.227858
# V8        0.067621
# V9       -0.099833
# V10      -0.254068
# V11       0.149826
# V12      -0.279967
# V13      -0.003893
# V14      -0.330588
# V15      -0.003449
# V16      -0.196613
# V17      -0.340760
# V18      -0.108612
# V19       0.036222
# V20       0.055006
# V21       0.057592
# V22       0.004898
# V23      -0.013732
# V24      -0.007493
# V25       0.003076
# V26       0.004755
# V27       0.047635
# V28       0.021806
# Amount    0.046813
# Name: Class, dtype: float64

# %%
# removing 'V13','V15','V22','V23','V24','V25','V26' columns since they have weak correlation with target feature Class
df = df.drop(columns=['V13','V15','V22','V23','V24','V25','V26'], axis=1)

# %% [markdown]
# <a id="imbalance"></a>
# ## 2.7. Handling Imbalance Data

# %%
X = df.drop('Class', axis=1)
y = df['Class']

# %%
from imblearn.under_sampling import RandomUnderSampler

random_under_sampler = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = random_under_sampler.fit_resample(X, y)

# %%
print(X_resampled.shape, y_resampled.shape)
# Out:
# (946, 23) (946,)

# %%
import joblib

# %%
# Save the cleaned DataFrame to a CSV file
df.to_csv(r'C:\Users\dell\FINAL_CAPSTONE_PROJECT\find-default-prediction-of-credit-card-fraud)\dataset(s)\cleaned_dataset.csv', index=False)

# %% [markdown]
# # -----------------------------------------------------------------------------------------

# %% [markdown]
# <a id='scorecard'></a>
# # 3. SCORE CARD

# %%
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, roc_auc_score

# %%
# Create an empty DataFrame to store the scores for various algorithms
score_card = pd.DataFrame(columns=['Model', 'AUC Score', 'Precision Score', 'Recall Score',
                                   'Accuracy Score', 'f1-score'])

# Function to append the result table for all performance scores
# Performance measures considered for model comparison are 'AUC Score', 'Precision Score', 'Recall Score', 'Accuracy Score', and 'f1-score'
def update_scorecard(model, test, pred, prob):
    global score_card
    # Create a new dataframe 'new_scorecard'
    new_scorecard = pd.DataFrame({
        'Model': [model],
        'AUC Score': [roc_auc_score(test, prob)],
        'Precision Score': [precision_score(test, pred)],
        'Recall Score': [recall_score(test, pred)],
        'Accuracy Score': [accuracy_score(test, pred)],
        'f1-score': [f1_score(test, pred)]
    })

    # Append the new scorecard to the global score_card DataFrame
    score_card = pd.concat([score_card, new_scorecard], ignore_index=True)

# Function to remove a model's scores from the score_card by index
def remove_model_by_index(index):
    global score_card
    # Drop the specified row by index and reset the index
    score_card = score_card.drop(index).reset_index(drop=True)

# %% [markdown]
# <a id='sd'></a>
# # 4. Train Test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled,y_resampled, test_size=0.2, stratify=y_resampled, random_state=42)

# %% [markdown]
# <a id='model'></a>
# # 5. Modelling

# %% [markdown]
# <a id='log_model'></a>
# ## 5.1. Logistic Regression Model

# %%
log_model = LogisticRegression(max_iter=1000)
result_log_model = log_model.fit(X_train,y_train)

# %%
y_pred_log = result_log_model.predict(X_test)
y_prob_log = result_log_model.predict_proba(X_test)[:, 1] # for auc score

# %% [markdown]
# <a id='eval'></a>
# ## 5.1.1 Model evaluation

# %%
update_scorecard('Logistic_regression_initial', y_test, y_pred_log, y_prob_log)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_548\2128808291.py:20: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   score_card = pd.concat([score_card, new_scorecard], ignore_index=True)

# %%
score_card
# Out:
#                          Model  AUC Score  Precision Score  Recall Score  \
# 0  Logistic_regression_initial   0.978726         0.977528      0.915789
#
#    Accuracy Score  f1-score
# 0        0.947368  0.945652

# %% [markdown]
# <a id='ar_curve'></a>
# ## 5.1.2 AUC ROC Curve

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
# Predict probabilities for the test set
y_prob = log_model.predict_proba(X_test)[:, 1]  # Probability of positive class

# Calculate the AUC score
auc_score = roc_auc_score(y_test, y_prob)
print(f'AUC Score: {auc_score:.4f}')

# Compute the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# Plot the AUC-ROC curve
plt.figure(figsize=(8, 6))
sns.lineplot(x=fpr, y=tpr, label=f'AUC = {auc_score:.4f}', color='blue')
plt.plot([0, 1], [0, 1], linestyle='--', color='red')  # Dashed diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Logistic Regression initial model')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# AUC Score: 0.9787
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <a id='hyp_tune'></a>
# ## 5.1.3 Hyperparameter Tuning

# %%
# Define the model
log_m = LogisticRegression(random_state=42)

# Define the hyperparameters and their values
param_grid = {
    'solver':['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga'],
    'penalty': ['l1', 'l2'],
    'C': [0.01, 0.1, 1, 10, 100],
    'max_iter': [100, 200, 300, 500, 1000]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search = GridSearchCV(
    estimator=log_m,
    param_grid=param_grid,
    scoring='f1',
    cv=5, 
    n_jobs=-1
)

# Fit the grid search
grid_search.fit(X_train, y_train)

# Get the best parameters and best score
print(f"Best Parameters: {grid_search.best_params_}")
# Out:
# Best Parameters: {'C': 0.1, 'max_iter': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# D:\Anaconda - Data Science\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 500 fits failed out of a total of 1500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 125 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\Anaconda - Data Science\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Anaconda - Data Science\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda - Data Science\Lib\site-packages\sklearn\linear_model\_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 125 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\Anaconda - Data Science\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Anaconda - Data Science\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda - Data Science\Lib\site-packages\sklearn\linear_model\_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 125 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\Anaconda - Data Science\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Anaconda - Data Science\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda - Data Science\Lib\site-packages\sklearn\linear_model\_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cholesky supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 125 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\Anaconda - Data Science\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Anaconda - Data Science\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda - Data Science\Lib\site-packages\sklearn\linear_model\_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# D:\Anaconda - Data Science\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan 0.85331761        nan        nan        nan 0.92300027
#  0.94467801 0.94329556 0.94467801 0.94467801 0.94628596 0.94501544
#         nan 0.85331761        nan        nan        nan 0.92156428
#  0.94467801 0.94329556 0.94467801 0.94467801 0.94628596 0.94762812
#         nan 0.85331761        nan        nan        nan 0.91980268
#  0.94467801 0.94329556 0.94467801 0.94467801 0.94467801 0.94628596
#         nan 0.85331761        nan        nan        nan 0.9182405
#  0.94467801 0.94329556 0.94467801 0.94467801 0.94467801 0.94628596
#         nan 0.85331761        nan        nan        nan 0.9182405
#  0.94467801 0.94329556 0.94467801 0.94467801 0.94467801 0.94628596
#         nan 0.94783327        nan        nan        nan 0.95077134
#  0.95268315 0.94749149 0.95268315 0.95268315 0.94861413 0.94752286
#         nan 0.94783327        nan        nan        nan 0.9504451
#  0.95268315 0.94749149 0.95268315 0.95268315 0.95137715 0.94861413
#         nan 0.94783327        nan        nan        nan 0.94915511
#  0.95268315 0.94749149 0.95268315 0.95268315 0.95268315 0.94992121
#         nan 0.94783327        nan        nan        nan 0.95078671
#  0.95268315 0.94749149 0.95268315 0.95268315 0.95268315 0.95137715
#         nan 0.94783327        nan        nan        nan 0.94933077
#  0.95268315 0.94749149 0.95268315 0.95268315 0.95268315 0.95268315
#         nan 0.94896294        nan        nan        nan 0.94625134
#  0.94752215 0.95045792 0.94752215 0.94752215 0.94603555 0.94625134
#         nan 0.94896294        nan        nan        nan 0.94878008
#  0.94752215 0.95045792 0.94752215 0.94752215 0.94735972 0.94603555
#         nan 0.94896294        nan        nan        nan 0.94878008
#  0.94752215 0.95045792 0.94752215 0.94752215 0.94879571 0.94735972
#         nan 0.94896294        nan        nan        nan 0.95010425
#  0.94752215 0.95045792 0.94752215 0.94752215 0.94889963 0.94735972
#         nan 0.94896294        nan        nan        nan 0.94752695
#  0.94752215 0.95045792 0.94752215 0.94752215 0.94752215 0.94889963
#         nan 0.94395441        nan        nan        nan 0.94625134
#  0.94395441 0.9454295  0.94395441 0.94395441 0.94603555 0.94625134
#         nan 0.94395441        nan        nan        nan 0.94749149
#  0.94395441 0.9454295  0.94395441 0.94395441 0.94735972 0.94603555
#         nan 0.94395441        nan        nan        nan 0.94881566
#  0.94395441 0.9454295  0.94395441 0.94395441 0.9501732  0.94735972
#         nan 0.94395441        nan        nan        nan 0.94881566
#  0.94395441 0.9454295  0.94395441 0.94395441 0.94889963 0.94879571
#         nan 0.94395441        nan        nan        nan 0.94889963
#  0.94395441 0.9454295  0.94395441 0.94395441 0.95045792 0.94889963
#         nan 0.94253795        nan        nan        nan 0.94625134
#  0.94395441 0.94395441 0.94395441 0.94395441 0.94603555 0.94625134
#         nan 0.94253795        nan        nan        nan 0.94749149
#  0.94395441 0.94395441 0.94395441 0.94395441 0.94735972 0.94603555
#         nan 0.94253795        nan        nan        nan 0.94735972
#  0.94395441 0.94395441 0.94395441 0.94395441 0.9501732  0.94735972
#         nan 0.94253795        nan        nan        nan 0.9501732
#  0.94395441 0.94395441 0.94395441 0.94395441 0.94889963 0.9501732
#         nan 0.94253795        nan        nan        nan 0.94889963
#  0.94395441 0.94395441 0.94395441 0.94395441 0.95045792 0.94889963]
#   warnings.warn(

# %%
log_model_tuned = LogisticRegression(C=0.1, max_iter=100, penalty='l2', solver='lbfgs')

results_log_model_tuned = log_model_tuned.fit(X_train, y_train)
y_pred_log_model_tuned = results_log_model_tuned.predict(X_test)
y_prob_log__model_tuned = results_log_model_tuned.predict_proba(X_test)[:, 1]

# %% [markdown]
# <a id='eval_tune'></a>
# ## 5.1.4. Model Evaluation(Tune model)

# %%
update_scorecard('Logistic_regression_tuned', y_test, y_pred_log_model_tuned, y_prob_log__model_tuned)

# %%
score_card
# Out:
#                          Model  AUC Score  Precision Score  Recall Score  \
# 0  Logistic_regression_initial   0.978726         0.977528      0.915789
# 1    Logistic_regression_tuned   0.980942         1.000000      0.915789
#
#    Accuracy Score  f1-score
# 0        0.947368  0.945652
# 1        0.957895  0.956044

# %% [markdown]
# **we can see after tuning the hyperparameters our model performance increased**

# %% [markdown]
# <a id='ar_curve_tune'></a>
# ## 5.1.5 AUC ROC Curve(Tuned model)

# %%
# Predict probabilities for the test set
y_prob_tuned = log_model_tuned.predict_proba(X_test)[:, 1]  # Probability of positive class

# Calculate the AUC score
auc_score = roc_auc_score(y_test, y_prob_tuned)
print(f'AUC Score: {auc_score:.4f}')

# Compute the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob_tuned)

# Plot the AUC-ROC curve
plt.figure(figsize=(8, 6))
sns.lineplot(x=fpr, y=tpr, label=f'AUC = {auc_score:.4f}', color='green')

plt.plot([0, 1], [0, 1], linestyle='--', color='red')  # Dashed diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Logistic Regression tuned model')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# AUC Score: 0.9809
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <a id='model_val'></a>
# ## 5.1.6 Model Validation

# %%
from sklearn.model_selection import cross_val_score

# Perform cross-validation with the best model
cv_scores = cross_val_score(log_model_tuned, X_train, y_train, cv=5, scoring='roc_auc')

print("Cross-Validation AUC Scores:", cv_scores)
print("Mean AUC Score:", cv_scores.mean())
# Out:
# Cross-Validation AUC Scores: [0.98182133 0.98087719 0.99421053 0.99964912 0.97964912]
# Mean AUC Score: 0.9872414589104339

# %% [markdown]
# <a id='feat_imp'></a>
# ## 5.1.7 Feature Importance

# %%
# Get the coefficients of the features
coefficients = log_model_tuned.coef_[0]

# Create a DataFrame for better visualization
feature_importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Coefficient': coefficients
}).sort_values(by='Coefficient', ascending=False)

# Plot the coefficients
plt.figure(figsize=(10, 8))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Coefficient'], color='blue')
plt.title('Feature Importance from Logistic Regression Coefficients')
plt.xlabel('Coefficient')
plt.show()

# %% [markdown]
# **Features - `Amount,V4,V5` have higher positive coefficients, indicating they play a significant role in identifying fraudulent transactions.
# Conversely, features like `V8,V14,V12` have larger negative coefficients, indicating they are significant in identifying non-fraudulent transactions.**

# %% [markdown]
# <a id='conf_mat_log'></a>
# ## 5.1.8 Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred_log_model_tuned)

# Create a ConfusionMatrixDisplay object
disp = ConfusionMatrixDisplay(confusion_matrix=cm)

# Plot the confusion matrix
disp.plot(cmap='Blues')
plt.title('Confusion Matrix for Logistic Regression')
plt.show()

# %% [markdown]
#     95(True Positives (TP)): The model correctly predicted 88 fraudulent transactions as fraudulent.
#     87(True Negatives (TN)): The model correctly predicted 94 non-fraudulent transactions as non-fraudulent.
#     8(False Positives (FP)): The model incorrectly predicted 1 non-fraudulent transaction as fraudulent.
#     0(False Negatives (FN)): The model incorrectly predicted 7 fraudulent transactions as non-fraudulent.

# %%
import joblib

# %%
# Save the model using joblib
joblib.dump(log_model_tuned, 'C:/Users/dell/FINAL_CAPSTONE_PROJECT/find-default-prediction-of-credit-card-fraud)/models/logistic_regression_model.joblib')
# Out:
# ['C:/Users/dell/FINAL_CAPSTONE_PROJECT/find-default-prediction-of-credit-card-fraud)/models/logistic_regression_model.joblib']

# %% [markdown]
# # -----------------------------------------------------------------------------------------

# %% [markdown]
# <a id='rfc_model'></a>
# ## 5.2. Random Forest Classifier Model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Initialize the Random Forest model
rf_model = RandomForestClassifier()

# Train the model
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rf = rf_model.predict(X_test)
y_prob_rf = rf_model.predict_proba(X_test)[:, 1]

# %% [markdown]
# <a id='eval_rf'></a>
# ## 5.2.1 Model evaluation

# %%
update_scorecard('Random Forest Classifier Initial Model', y_test, y_pred_rf, y_prob_rf)

# %%
score_card
# Out:
#                                     Model  AUC Score  Precision Score  \
# 0             Logistic_regression_initial   0.978726         0.977528
# 1               Logistic_regression_tuned   0.980942         1.000000
# 2  Random Forest Classifier Initial Model   0.986316         1.000000
#
#    Recall Score  Accuracy Score  f1-score
# 0      0.915789        0.947368  0.945652
# 1      0.915789        0.957895  0.956044
# 2      0.936842        0.968421  0.967391

# %% [markdown]
# <a id='ar_curve_rf'></a>
# ## 5.2.2 AUC ROC Curve

# %%
# Predict probabilities for the test set
y_prob = rf_model.predict_proba(X_test)[:, 1]  # Probability of positive class

# Calculate the AUC score
auc_score = roc_auc_score(y_test, y_prob)
print(f'AUC Score: {auc_score:.4f}')

# Compute the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# Plot the AUC-ROC curve
plt.figure(figsize=(8, 6))
sns.lineplot(x=fpr, y=tpr, label=f'AUC = {auc_score:.4f}', color='blue')
plt.plot([0, 1], [0, 1], linestyle='--', color='red')  # Dashed diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Random Forest Classifier initial model')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# AUC Score: 0.9863
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <a id='hyp_tune_rf'></a>
# ## 5.2.3 Hyperparameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
# Initialize the Random Forest model
rf = RandomForestClassifier(random_state=42)

# Define the parameter grid
param_dist = {
    'n_estimators': [100, 200, 500],  
    'max_features': ['sqrt', 'log2'],  
    'max_depth': [10, 15, 20],  
    'min_samples_split': [2, 5, 10],  
    'min_samples_leaf': [1, 2, 4, 6],  
    'max_leaf_nodes': [10, 20, 30, 40],
    'max_samples': [0.25, 0.5, 0.75]
}

# %%
# Set up the GridSearchCV
random_search = RandomizedSearchCV(
                    estimator=rf, 
                    n_iter=100,
                    param_distributions=param_dist, 
                    cv=5,
                    n_jobs=-1,
                    random_state=42,
                    scoring='f1',)

# Fit GridSearchCV to the data
random_search.fit(X_train, y_train)

# Print the best parameters and the best AUC score
print(f"Best Parameters: {random_search.best_params_}")
# Out:
# Best Parameters: {'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_samples': 0.75, 'max_leaf_nodes': 20, 'max_features': 'log2', 'max_depth': 10}

# %%
rf_model_tuned = RandomForestClassifier(
                                n_estimators=100,  
                                max_features='log2',  
                                max_depth=10,  
                                min_samples_split=10,  
                                min_samples_leaf=1,  
                                max_leaf_nodes=20,
                                max_samples=0.75)

result_rf_model_tuned = rf_model_tuned.fit(X_train, y_train)

y_pred_rf_tuned = rf_model_tuned.predict(X_test)
y_prob_rf_tuned = rf_model_tuned.predict_proba(X_test)[:, 1]

# %% [markdown]
# <a id='eval_tune_rf'></a>
# ## 5.2.4. Model Evaluation(Tune model)

# %%
update_scorecard('Random Forest Classifier Tuned Model', y_test, y_pred_rf_tuned, y_prob_rf_tuned)
score_card
# Out:
#                                     Model  AUC Score  Precision Score  \
# 0             Logistic_regression_initial   0.978726         0.977528
# 1               Logistic_regression_tuned   0.980942         1.000000
# 2  Random Forest Classifier Initial Model   0.986316         1.000000
# 3    Random Forest Classifier Tuned Model   0.984266         1.000000
#
#    Recall Score  Accuracy Score  f1-score
# 0      0.915789        0.947368  0.945652
# 1      0.915789        0.957895  0.956044
# 2      0.936842        0.968421  0.967391
# 3      0.936842        0.968421  0.967391

# %% [markdown]
# **we can see after tuning the hyperparameters model performance remains the same**

# %% [markdown]
# <a id='ar_curve_tune_rf'></a>
# ## 5.2.5 AUC ROC Curve(Tuned model)

# %%
# Predict probabilities for the test set
y_prob_tuned = rf_model_tuned.predict_proba(X_test)[:, 1]  # Probability of positive class

# Calculate the AUC score
auc_score = roc_auc_score(y_test, y_prob_tuned)
print(f'AUC Score: {auc_score:.4f}')

# Compute the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob_tuned)

# Plot the AUC-ROC curve
plt.figure(figsize=(8, 6))
sns.lineplot(x=fpr, y=tpr, label=f'AUC = {auc_score:.4f}', color='green')
plt.plot([0, 1], [0, 1], linestyle='--', color='red')  # Dashed diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Random Forest Classifier tuned model')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# AUC Score: 0.9843
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <a id='model_val_rf'></a>
# ## 5.2.6 Model Validation

# %%
# Perform cross-validation with the best model
cv_scores = cross_val_score(rf_model_tuned, X_train, y_train, cv=5, scoring='roc_auc')

print("Cross-Validation AUC Scores:", cv_scores)
print("Mean AUC Score:", cv_scores.mean())
# Out:
# Cross-Validation AUC Scores: [0.99359418 0.96929825 0.99508772 0.99982456 0.98701754]
# Mean AUC Score: 0.9889644506001847

# %% [markdown]
# <a id='feat_imp_rf'></a>
# ## 5.2.7 Feature Importance

# %%
# Get feature importances
feature_importances = rf_model_tuned.feature_importances_

# Create a DataFrame for better visualization
feature_importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(10, 8))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='red')
plt.gca().invert_yaxis()  # To display the highest importance feature at the top
plt.title('Feature Importance from Random Forest Classifier')
plt.xlabel('Importance')
plt.show()

# %% [markdown]
# **Features like `V14,V12,V10` have more influence in the decision making and features like `V5,V1,Time` have less influence in the desicion making**

# %% [markdown]
# <a id='conf_mat_rf'></a>
# ## 5.2.8 Confusion Matrix

# %%
# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred_rf_tuned)

# Create a ConfusionMatrixDisplay object
disp = ConfusionMatrixDisplay(confusion_matrix=cm)

# Plot the confusion matrix
disp.plot(cmap='Blues')
plt.title('Confusion Matrix for Random Forest Classifier')
plt.show()

# %% [markdown]
#     95(True Positives (TP)): The model correctly predicted 87 fraudulent transactions as fraudulent.
#     89(True Negatives (TN)): The model correctly predicted 95 non-fraudulent transactions as non-fraudulent.
#     6(False Positives (FP)): The model incorrectly predicted 0 non-fraudulent transaction as fraudulent.
#     0(False Negatives (FN)): The model incorrectly predicted 8 fraudulent transactions as non-fraudulent.

# %%
# Save the model using joblib
joblib.dump(rf_model_tuned, 'C:/Users/dell/FINAL_CAPSTONE_PROJECT/find-default-prediction-of-credit-card-fraud)/models/random_forest_classifier_model.joblib')
# Out:
# ['C:/Users/dell/FINAL_CAPSTONE_PROJECT/find-default-prediction-of-credit-card-fraud)/models/random_forest_classifier_model.joblib']

# %% [markdown]
# # -----------------------------------------------------------------------------------------

# %% [markdown]
# <a id='dtc_model'></a>
# ## 5.3 Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# Define the Decision Tree model
dt_model_ini = DecisionTreeClassifier(random_state=42)

# Train the model
dt_results = dt_model_ini.fit(X_train, y_train)

# Make predictions
y_pred_dt = dt_results.predict(X_test)
y_prob_dt = dt_results.predict_proba(X_test)[:, 1]

# %% [markdown]
# <a id='eval_dt'></a>
# ## 5.3.1 Model evaluation

# %%
update_scorecard('Decision Tree Classifier Initial Model', y_test, y_pred_dt, y_prob_dt)
score_card
# Out:
#                                     Model  AUC Score  Precision Score  \
# 0             Logistic_regression_initial   0.978726         0.977528
# 1               Logistic_regression_tuned   0.980942         1.000000
# 2  Random Forest Classifier Initial Model   0.986316         1.000000
# 3    Random Forest Classifier Tuned Model   0.984266         1.000000
# 4  Decision Tree Classifier Initial Model   0.947368         0.956989
#
#    Recall Score  Accuracy Score  f1-score
# 0      0.915789        0.947368  0.945652
# 1      0.915789        0.957895  0.956044
# 2      0.936842        0.968421  0.967391
# 3      0.936842        0.968421  0.967391
# 4      0.936842        0.947368  0.946809

# %% [markdown]
# <a id='ar_curve_dt'></a>
# ## 5.3.2 AUC ROC Curve

# %%
# Predict probabilities for the test set
y_prob = dt_model_ini.predict_proba(X_test)[:, 1]  # Probability of positive class

# Calculate the AUC score
auc_score = roc_auc_score(y_test, y_prob)
print(f'AUC Score: {auc_score:.4f}')

# Compute the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# Plot the AUC-ROC curve
plt.figure(figsize=(8, 6))
sns.lineplot(x=fpr, y=tpr, label=f'AUC = {auc_score:.4f}', color='blue')
plt.plot([0, 1], [0, 1], linestyle='--', color='red')  # Dashed diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Tree Classifier initial model')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# AUC Score: 0.9474
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <a id='hyp_tune_dt'></a>
# ## 5.3.3 Hyperparameter Tuning

# %%
# Define the model
dt = DecisionTreeClassifier(random_state=42)

# Define the parameter grid for tuning
param_dist = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 5, 10],
    'max_features': [None, 'sqrt', 'log2'],
    'class_weight': [None, 'balanced']
}

# %%
# Initialize RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=dt, 
    param_distributions=param_dist, 
    n_iter=100,  
    scoring='f1',  
    cv=5,  
    random_state=42,  
    n_jobs=-1)  

# Fit the random search model
random_search.fit(X_train, y_train)

# Print the best parameters
print("Best parameters found: ", random_search.best_params_)
# Out:
# Best parameters found:  {'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 30, 'criterion': 'gini', 'class_weight': 'balanced'}

# %%
dt_model_tuned = DecisionTreeClassifier(min_samples_split=10,
                                        min_samples_leaf=2,
                                        max_features=None,
                                        max_depth=30,
                                        criterion='gini',
                                        class_weight='balanced')

dt_results_tuned = dt_model_tuned.fit(X_train, y_train)

y_pred_dt_tuned = dt_results_tuned.predict(X_test)
y_prob_dt_tuned = dt_results_tuned.predict_proba(X_test)[:, 1]

# %% [markdown]
# <a id='eval_tune_dt'></a>
# ## 5.3.4. Model Evaluation(Tune model)

# %%
update_scorecard('Decision Tree Classifier Tuned Model', y_test, y_pred_dt_tuned, y_prob_dt_tuned)
score_card
# Out:
#                                     Model  AUC Score  Precision Score  \
# 0             Logistic_regression_initial   0.978726         0.977528
# 1               Logistic_regression_tuned   0.980942         1.000000
# 2  Random Forest Classifier Initial Model   0.986316         1.000000
# 3    Random Forest Classifier Tuned Model   0.984266         1.000000
# 4  Decision Tree Classifier Initial Model   0.947368         0.956989
# 5    Decision Tree Classifier Tuned Model   0.956122         0.988636
#
#    Recall Score  Accuracy Score  f1-score
# 0      0.915789        0.947368  0.945652
# 1      0.915789        0.957895  0.956044
# 2      0.936842        0.968421  0.967391
# 3      0.936842        0.968421  0.967391
# 4      0.936842        0.947368  0.946809
# 5      0.915789        0.952632  0.950820

# %% [markdown]
# <a id='ar_curve_tune_dt'></a>
# ## 5.3.5 AUC ROC Curve(Tuned model)

# %%
# Predict probabilities for the test set
y_prob_tuned = dt_model_tuned.predict_proba(X_test)[:, 1]  # Probability of positive class

# Calculate the AUC score
auc_score = roc_auc_score(y_test, y_prob_tuned)
print(f'AUC Score: {auc_score:.4f}')

# Compute the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob_tuned)

# Plot the AUC-ROC curve
plt.figure(figsize=(8, 6))
sns.lineplot(x=fpr, y=tpr, label=f'AUC = {auc_score:.4f}', color='green')
plt.plot([0, 1], [0, 1], linestyle='--', color='red')  # Dashed diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Tree Classifier tuned model')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# AUC Score: 0.9561
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <a id='model_val_dt'></a>
# ## 5.3.6 Model Validation

# %%
# Perform cross-validation with the best model
cv_scores = cross_val_score(dt_model_ini, X_train, y_train, cv=5, scoring='roc_auc')

print("Cross-Validation AUC Scores:", cv_scores)
print("Mean AUC Score:", cv_scores.mean())
# Out:
# Cross-Validation AUC Scores: [0.96710526 0.93350877 0.96008772 0.98       0.94719298]
# Mean AUC Score: 0.9575789473684211

# %% [markdown]
# <a id='feat_imp_dt'></a>
# ## 5.3.7 Feature Importance

# %%
# Get feature importances
feature_importances = dt_model_ini.feature_importances_

# Create a DataFrame for better visualization
feature_importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(10, 8))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='green')
plt.gca().invert_yaxis()  # To display the highest importance feature at the top
plt.title('Feature Importance from Decision Tree Classifier')
plt.xlabel('Importance')
plt.show()

# %% [markdown]
# **Features like `V14,Amount,V12` have more influence in decision making as compared to all the remainig features like `V1,V16,V10,V9,V7,V20,V6,V5`**

# %% [markdown]
# <a id='conf_mat_dt'></a>
# ## 5.3.8 Confusion Matrix

# %%
# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred_dt_tuned)

# Create a ConfusionMatrixDisplay object
disp = ConfusionMatrixDisplay(confusion_matrix=cm)

# Plot the confusion matrix
disp.plot(cmap='Blues')
plt.title('Confusion Matrix for Decision Tree Classifier')
plt.show()

# %% [markdown]
#     94(True Positives (TP)): The model correctly predicted 87 fraudulent transactions as fraudulent.
#     87(True Negatives (TN)): The model correctly predicted 95 non-fraudulent transactions as non-fraudulent.
#     8(False Positives (FP)): The model incorrectly predicted 0 non-fraudulent transaction as fraudulent.
#     1(False Negatives (FN)): The model incorrectly predicted 8 fraudulent transactions as non-fraudulent.

# %%
# Save the model using joblib
joblib.dump(dt_model_tuned, 'C:/Users/dell/FINAL_CAPSTONE_PROJECT/find-default-prediction-of-credit-card-fraud)/models/decision_tree_classifier_model.joblib')
# Out:
# ['C:/Users/dell/FINAL_CAPSTONE_PROJECT/find-default-prediction-of-credit-card-fraud)/models/decision_tree_classifier_model.joblib']

# %% [markdown]
# # --------------------------------------------------------------------------

# %% [markdown]
# <a id='svm_model'></a>
# ## 5.4 Support Vector Machines(SVM) Model

# %%
from sklearn.svm import SVC

# %%
svm_model = SVC(random_state=42, probability=True)
svm_results = svm_model.fit(X_train, y_train)

y_pred_svm = svm_results.predict(X_test)
y_prob_svm = svm_results.predict_proba(X_test)[:, 1]

# %% [markdown]
# <a id='eval_svm'></a>
# ## 5.4.1 Model evaluation

# %%
update_scorecard('SVM initial Model', y_test, y_pred_svm, y_prob_svm)
score_card
# Out:
#                                     Model  AUC Score  Precision Score  \
# 0             Logistic_regression_initial   0.978726         0.977528
# 1               Logistic_regression_tuned   0.980942         1.000000
# 2  Random Forest Classifier Initial Model   0.986316         1.000000
# 3    Random Forest Classifier Tuned Model   0.984266         1.000000
# 4  Decision Tree Classifier Initial Model   0.947368         0.956989
# 5    Decision Tree Classifier Tuned Model   0.956122         0.988636
# 6                       SVM initial Model   0.982161         1.000000
#
#    Recall Score  Accuracy Score  f1-score
# 0      0.915789        0.947368  0.945652
# 1      0.915789        0.957895  0.956044
# 2      0.936842        0.968421  0.967391
# 3      0.936842        0.968421  0.967391
# 4      0.936842        0.947368  0.946809
# 5      0.915789        0.952632  0.950820
# 6      0.884211        0.942105  0.938547

# %% [markdown]
# <a id='ar_curve_svm'></a>
# ## 5.4.2 AUC ROC Curve

# %%
# Predict probabilities for the test set
y_prob = svm_model.predict_proba(X_test)[:, 1]  # Probability of positive class

# Calculate the AUC score
auc_score = roc_auc_score(y_test, y_prob)
print(f'AUC Score: {auc_score:.4f}')

# Compute the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# Plot the AUC-ROC curve
plt.figure(figsize=(8, 6))
sns.lineplot(x=fpr, y=tpr, label=f'AUC = {auc_score:.4f}', color='pink')
plt.plot([0, 1], [0, 1], linestyle='--', color='red')  # Dashed diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for SVM initial model')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# AUC Score: 0.9822
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <a id='hyp_tune_svm'></a>
# ## 5.4.3 Hyperparameter Tuning

# %%
# Define the SVM model
svm = SVC(probability=True)

# Define the parameter grid
param_grid = {
    'C': [0.1, 1, 10, 100, 1000],
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'degree': [2, 3, 4, 5],
    'gamma': ['scale', 'auto', 0.01, 0.1, 1, 10],
    'tol': [0.0001, 0.001, 0.01, 0.1],
    'class_weight': [None, 'balanced'],
    'max_iter': [100, 500, 1000, -1]
}

# %%
# Set up the RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=svm,
    param_distributions=param_grid,
    n_iter=50,  
    scoring='f1', 
    cv=5, 
    verbose=2,
    random_state=42,
    n_jobs=-1 
)

# Fit the random search model
random_search.fit(X_train, y_train)

# Get the best parameters and score
print("Best Parameters:", random_search.best_params_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best Parameters: {'tol': 0.001, 'max_iter': 1000, 'kernel': 'rbf', 'gamma': 0.01, 'degree': 2, 'class_weight': 'balanced', 'C': 10}

# %%
svm_model_tuned = SVC(probability=True,
                     C=10,
                     class_weight='balanced',
                     tol=0.001,
                     max_iter=1000,
                     kernel='rbf',
                     gamma=0.01,
                     degree=2)

result_svm_tuned = svm_model_tuned.fit(X_train, y_train)

y_pred_svm_tuned = result_svm_tuned.predict(X_test)
y_prob_svm_tuned = result_svm_tuned.predict_proba(X_test)[:, 1]

# %% [markdown]
# <a id='eval_tune_svm'></a>
# ## 5.4.4. Model Evaluation(Tune model)

# %%
update_scorecard('SVM tuned model', y_test, y_pred_svm_tuned, y_prob_svm_tuned)
score_card
# Out:
#                                     Model  AUC Score  Precision Score  \
# 0             Logistic_regression_initial   0.978726         0.977528
# 1               Logistic_regression_tuned   0.980942         1.000000
# 2  Random Forest Classifier Initial Model   0.986316         1.000000
# 3    Random Forest Classifier Tuned Model   0.984266         1.000000
# 4  Decision Tree Classifier Initial Model   0.947368         0.956989
# 5    Decision Tree Classifier Tuned Model   0.956122         0.988636
# 6                       SVM initial Model   0.982161         1.000000
# 7                         SVM tuned model   0.984377         1.000000
#
#    Recall Score  Accuracy Score  f1-score
# 0      0.915789        0.947368  0.945652
# 1      0.915789        0.957895  0.956044
# 2      0.936842        0.968421  0.967391
# 3      0.936842        0.968421  0.967391
# 4      0.936842        0.947368  0.946809
# 5      0.915789        0.952632  0.950820
# 6      0.884211        0.942105  0.938547
# 7      0.926316        0.963158  0.961749

# %% [markdown]
# <a id='ar_curve_tune_svm'></a>
# ## 5.4.5 AUC ROC Curve(Tuned model)

# %%
# Predict probabilities for the test set
y_prob = svm_model_tuned.predict_proba(X_test)[:, 1]  # Probability of positive class

# Calculate the AUC score
auc_score = roc_auc_score(y_test, y_prob)
print(f'AUC Score: {auc_score:.4f}')

# Compute the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# Plot the AUC-ROC curve
plt.figure(figsize=(8, 6))
sns.lineplot(x=fpr, y=tpr, label=f'AUC = {auc_score:.4f}', color='pink')
plt.plot([0, 1], [0, 1], linestyle='--', color='red')  # Dashed diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for SVM tuned model')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# AUC Score: 0.9844
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <a id='mode_val_svm'></a>
# ## 5.4.6 Model Validation

# %%
# Perform cross-validation with the best model
cv_scores = cross_val_score(svm_model_tuned, X_train, y_train, cv=5, scoring='roc_auc')

print("Cross-Validation AUC Scores:", cv_scores)
print("Mean AUC Score:", cv_scores.mean())
# Out:
# Cross-Validation AUC Scores: [0.98649584 0.98070175 0.99403509 1.         0.97578947]
# Mean AUC Score: 0.987404432132964

# %% [markdown]
# <a id='feat_imp_svm'></a>
# ## 5.4.7 Feature Importance

# %%
from sklearn.inspection import permutation_importance

# %%
# Calculate permutation importance
result = permutation_importance(svm_model_tuned, X_test, y_test, n_repeats=30, random_state=42)

# Create a DataFrame for visualization
feature_importance = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': result.importances_mean
}).sort_values(by='Importance', ascending=False)

# Plot the feature importance
plt.figure(figsize=(8, 8))
plt.barh(feature_importance['Feature'], feature_importance['Importance'], color='blue')
plt.xlabel('Mean Importance')
plt.title('Feature Importance from Permutation Importance (SVM)')
plt.gca().invert_yaxis()  # Highest importance at the top
plt.show()

# %% [markdown]
# **Features like `V14,V12,V17,V10` have more influence in decision making as compared features like `V28,V27,Time,V6`**

# %% [markdown]
# <a id='conf_mat_svm'></a>
# ## 5.4.8 Confusion Matrix

# %%
# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred_svm_tuned)

# Create a ConfusionMatrixDisplay object
disp = ConfusionMatrixDisplay(confusion_matrix=cm)

# Plot the confusion matrix
disp.plot(cmap='Blues')
plt.title('Confusion Matrix for SVM model')
plt.show()

# %% [markdown]
#     95(True Positives (TP)): The model correctly predicted 87 fraudulent transactions as fraudulent.
#     88(True Negatives (TN)): The model correctly predicted 95 non-fraudulent transactions as non-fraudulent.
#     7(False Positives (FP)): The model incorrectly predicted 0 non-fraudulent transaction as fraudulent.
#     0(False Negatives (FN)): The model incorrectly predicted 8 fraudulent transactions as non-fraudulent.

# %%
# Save the model using joblib
joblib.dump(svm_model_tuned, 'C:/Users/dell/FINAL_CAPSTONE_PROJECT/find-default-prediction-of-credit-card-fraud)/models/svm_model.joblib')
# Out:
# ['C:/Users/dell/FINAL_CAPSTONE_PROJECT/find-default-prediction-of-credit-card-fraud)/models/svm_model.joblib']

# %% [markdown]
# # -----------------------------------------------------------------------------------------

# %% [markdown]
# <a id='gbm_model'></a>
# ## 5.5 Gradient Boosting Classifier Model

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbm_model = GradientBoostingClassifier(random_state=42)

# Train the model
results_gbm = gbm_model.fit(X_train, y_train)

# Make predictions
y_pred_gbm = results_gbm.predict(X_test)
y_prob_gbm = results_gbm.predict_proba(X_test)[:, 1]

# %% [markdown]
# <a id='eval_gbm'></a>
# ## 5.5.1 Model evaluation

# %%
update_scorecard('Gradient Boosting Classifier initial model', y_test, y_pred_gbm, y_prob_gbm)
score_card
# Out:
#                                         Model  AUC Score  Precision Score  \
# 0                 Logistic_regression_initial   0.978726         0.977528
# 1                   Logistic_regression_tuned   0.980942         1.000000
# 2      Random Forest Classifier Initial Model   0.986316         1.000000
# 3        Random Forest Classifier Tuned Model   0.984266         1.000000
# 4      Decision Tree Classifier Initial Model   0.947368         0.956989
# 5        Decision Tree Classifier Tuned Model   0.956122         0.988636
# 6                           SVM initial Model   0.982161         1.000000
# 7                             SVM tuned model   0.984377         1.000000
# 8  Gradient Boosting Classifier initial model   0.992244         1.000000
#
#    Recall Score  Accuracy Score  f1-score
# 0      0.915789        0.947368  0.945652
# 1      0.915789        0.957895  0.956044
# 2      0.936842        0.968421  0.967391
# 3      0.936842        0.968421  0.967391
# 4      0.936842        0.947368  0.946809
# 5      0.915789        0.952632  0.950820
# 6      0.884211        0.942105  0.938547
# 7      0.926316        0.963158  0.961749
# 8      0.936842        0.968421  0.967391

# %% [markdown]
# <a id='ar_curve_gbm'></a>
# ## 5.5.2 AUC ROC Curve

# %%
# Predict probabilities for the test set
y_prob = gbm_model.predict_proba(X_test)[:, 1]  # Probability of positive class

# Calculate the AUC score
auc_score = roc_auc_score(y_test, y_prob)
print(f'AUC Score: {auc_score:.4f}')

# Compute the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# Plot the AUC-ROC curve
plt.figure(figsize=(8, 6))
sns.lineplot(x=fpr, y=tpr, label=f'AUC = {auc_score:.4f}', color='purple')
plt.plot([0, 1], [0, 1], linestyle='--', color='red')  # Dashed diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Gradient boosting classifier initial model')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# AUC Score: 0.9922
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <a id='hyp_tune_gbm'></a>
# ## 5.5.3 Hyperparameter Tuning

# %%
# Define the model
gbm = GradientBoostingClassifier(random_state=42)

# Define the parameter grid for RandomizedSearchCV
param_grid = {
    'n_estimators': [100, 200, 500, 1000],  
    'learning_rate': [0.01, 0.05, 0.1, 0.2],  
    'max_depth': [3, 4, 5, 6], 
    'min_samples_split': [2, 5, 10],  
    'min_samples_leaf': [1, 2, 4],  
    'max_features': ['sqrt', 'log2', None], 
    'subsample': [0.8, 0.9, 1.0] 
}

# %%
random_search = RandomizedSearchCV(
    estimator=gbm, 
    param_distributions=param_grid, 
    n_iter=50,  
    scoring='f1',  
    cv=5,  
    random_state=42,  
    n_jobs=-1  
)

# Fit the model to find the best parameters
random_search.fit(X_train, y_train)

# Print the best parameters and score
print("Best Parameters:", random_search.best_params_)
# Out:
# Best Parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 6, 'learning_rate': 0.01}

# %%
gbm_model_tuned = GradientBoostingClassifier(subsample=1.0,
                                             n_estimators=100, 
                                             min_samples_split=2,
                                             min_samples_leaf=1,
                                             max_features='log2', 
                                             max_depth=6, 
                                             learning_rate=0.01)

results_gbm_tuned = gbm_model_tuned.fit(X_train, y_train)

y_pred_gbm_tuned = results_gbm_tuned.predict(X_test)
y_prob_gbm_tuned = results_gbm_tuned.predict_proba(X_test)[:, 1]

# %% [markdown]
# <a id='eval_tune_gbm'></a>
# ## 5.5.4. Model Evaluation(Tune model)

# %%
update_scorecard('Gradient Boosting Classifier tuned model', y_test, y_pred_gbm_tuned, y_prob_gbm_tuned)
score_card
# Out:
#                                         Model  AUC Score  Precision Score  \
# 0                 Logistic_regression_initial   0.978726         0.977528
# 1                   Logistic_regression_tuned   0.980942         1.000000
# 2      Random Forest Classifier Initial Model   0.986316         1.000000
# 3        Random Forest Classifier Tuned Model   0.984266         1.000000
# 4      Decision Tree Classifier Initial Model   0.947368         0.956989
# 5        Decision Tree Classifier Tuned Model   0.956122         0.988636
# 6                           SVM initial Model   0.982161         1.000000
# 7                             SVM tuned model   0.984377         1.000000
# 8  Gradient Boosting Classifier initial model   0.992244         1.000000
# 9    Gradient Boosting Classifier tuned model   0.985485         1.000000
#
#    Recall Score  Accuracy Score  f1-score
# 0      0.915789        0.947368  0.945652
# 1      0.915789        0.957895  0.956044
# 2      0.936842        0.968421  0.967391
# 3      0.936842        0.968421  0.967391
# 4      0.936842        0.947368  0.946809
# 5      0.915789        0.952632  0.950820
# 6      0.884211        0.942105  0.938547
# 7      0.926316        0.963158  0.961749
# 8      0.936842        0.968421  0.967391
# 9      0.926316        0.963158  0.961749

# %% [markdown]
# <a id='ar_curve_tune_gbm'></a>
# ## 5.5.5 AUC ROC Curve(Tuned model)

# %%
# Predict probabilities for the test set
y_prob = gbm_model_tuned.predict_proba(X_test)[:, 1]  # Probability of positive class

# Calculate the AUC score
auc_score = roc_auc_score(y_test, y_prob)
print(f'AUC Score: {auc_score:.4f}')

# Compute the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# Plot the AUC-ROC curve
plt.figure(figsize=(8, 6))
sns.lineplot(x=fpr, y=tpr, label=f'AUC = {auc_score:.4f}', color='purple')
plt.plot([0, 1], [0, 1], linestyle='--', color='red')  # Dashed diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Gradient Boosting Classifier tuned model')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# AUC Score: 0.9855
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <a id='mode_val_gbm'></a>
# ## 5.5.6 Model Validation

# %%
# Perform cross-validation with the best model
cv_scores = cross_val_score(gbm_model_tuned, X_train, y_train, cv=5, scoring='roc_auc')

print("Cross-Validation AUC Scores:", cv_scores)
print("Mean AUC Score:", cv_scores.mean())
# Out:
# Cross-Validation AUC Scores: [0.98926593 0.96719298 0.99912281 1.         0.98807018]
# Mean AUC Score: 0.988730378578024

# %% [markdown]
# <a id='feat_imp_gbm'></a>
# ## 5.5.7 Feature Importance

# %%
# Get feature importance
feature_importance = gbm_model_tuned.feature_importances_

# Create a DataFrame to visualize feature importance
features = X_train.columns
importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importance
}).sort_values(by='Importance', ascending=False)

# Plot feature importance
plt.figure(figsize=(10, 8))
plt.barh(importance_df['Feature'], importance_df['Importance'], color='teal')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.title('Feature Importance in Gradient Boosting Classifier')
plt.gca().invert_yaxis()  # To display the most important features at the top
plt.show()

# %% [markdown]
# **features `V14,V12,V10` are making more influence in decision making, while features like `V1,Time,V5` are making less influence in decision making**

# %% [markdown]
# <a id='conf_mat_gbm'></a>
# ## 5.5.8 Confusion Matrix

# %%
# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred_gbm_tuned)

# Create a ConfusionMatrixDisplay object
disp = ConfusionMatrixDisplay(confusion_matrix=cm)

# Plot the confusion matrix
disp.plot(cmap='Blues')
plt.title('Confusion Matrix for Gradient Boosting Classifier model')
plt.show()

# %% [markdown]
#     95(True Positives (TP)): The model correctly predicted 87 fraudulent transactions as fraudulent.
#     88(True Negatives (TN)): The model correctly predicted 95 non-fraudulent transactions as non-fraudulent.
#     7(False Positives (FP)): The model incorrectly predicted 0 non-fraudulent transaction as fraudulent.
#     0(False Negatives (FN)): The model incorrectly predicted 8 fraudulent transactions as non-fraudulent.

# %%
# Save the model using joblib
joblib.dump(gbm_model, 'C:/Users/dell/FINAL_CAPSTONE_PROJECT/find-default-prediction-of-credit-card-fraud)/models/gbm_model.joblib')
# Out:
# ['C:/Users/dell/FINAL_CAPSTONE_PROJECT/find-default-prediction-of-credit-card-fraud)/models/gbm_model.joblib']

# %% [markdown]
# # ---------------------------------------------------------------------------------------

# %% [markdown]
# <a id='xgb_model'></a>
# ## 5.6 XGBoost Model

# %%
from xgboost import XGBClassifier

# %%
# Initialize the model
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)

# Train the model
results_xgb = xgb_model.fit(X_train, y_train)

# Make predictions
y_pred_xgb = results_xgb.predict(X_test)
y_prob_xgb = results_xgb.predict_proba(X_test)[:, 1]
# Out:
# D:\Anaconda - Data Science\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:12:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %% [markdown]
# <a id='eval_xgb'></a>
# ## 5.6.1 Model evaluation

# %%
update_scorecard('XGBoost initial Model', y_test, y_pred_xgb, y_prob_xgb)
score_card
# Out:
#                                          Model  AUC Score  Precision Score  \
# 0                  Logistic_regression_initial   0.978726         0.977528
# 1                    Logistic_regression_tuned   0.980942         1.000000
# 2       Random Forest Classifier Initial Model   0.986316         1.000000
# 3         Random Forest Classifier Tuned Model   0.984266         1.000000
# 4       Decision Tree Classifier Initial Model   0.947368         0.956989
# 5         Decision Tree Classifier Tuned Model   0.956122         0.988636
# 6                            SVM initial Model   0.982161         1.000000
# 7                              SVM tuned model   0.984377         1.000000
# 8   Gradient Boosting Classifier initial model   0.992244         1.000000
# 9     Gradient Boosting Classifier tuned model   0.985485         1.000000
# 10                       XGBoost initial Model   0.989363         1.000000
#
#     Recall Score  Accuracy Score  f1-score
# 0       0.915789        0.947368  0.945652
# 1       0.915789        0.957895  0.956044
# 2       0.936842        0.968421  0.967391
# 3       0.936842        0.968421  0.967391
# 4       0.936842        0.947368  0.946809
# 5       0.915789        0.952632  0.950820
# 6       0.884211        0.942105  0.938547
# 7       0.926316        0.963158  0.961749
# 8       0.936842        0.968421  0.967391
# 9       0.926316        0.963158  0.961749
# 10      0.926316        0.963158  0.961749

# %% [markdown]
# <a id='ar_curve_xgb'></a>
# ## 5.6.2 AUC ROC Curve

# %%
# Predict probabilities for the test set
y_prob = xgb_model.predict_proba(X_test)[:, 1]  # Probability of positive class

# Calculate the AUC score
auc_score = roc_auc_score(y_test, y_prob)
print(f'AUC Score: {auc_score:.4f}')

# Compute the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# Plot the AUC-ROC curve
plt.figure(figsize=(8, 6))
sns.lineplot(x=fpr, y=tpr, label=f'AUC = {auc_score:.4f}', color='blue')
plt.plot([0, 1], [0, 1], linestyle='--', color='red')  # Dashed diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for XGBoost initial model')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# AUC Score: 0.9894
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <a id='hyp_tune_xgb'></a>
# ## 5.6.3 Hyperparameter Tuning

# %%
# Define the model
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)

# Define the parameter grid for RandomizedSearchCV
param_grid = {
    'n_estimators': [100, 200, 500, 1000], 
    'learning_rate': [0.01, 0.05, 0.1, 0.2],  
    'max_depth': [3, 5, 7, 9],  
    'min_child_weight': [1, 3, 5, 7],
    'gamma': [0, 0.1, 0.2, 0.3],  
    'subsample': [0.6, 0.8, 1.0],  
    'colsample_bytree': [0.6, 0.8, 1.0],
    'scale_pos_weight': [1, 10, 20, 30], 
    'reg_alpha': [0, 0.1, 0.5, 1],  
    'reg_lambda': [0, 0.1, 0.5, 1]  
}

# %%
random_search = RandomizedSearchCV(
    estimator=xgb_model, 
    param_distributions=param_grid, 
    n_iter=50,  
    scoring='f1',  
    cv=5,  
    random_state=42, 
    n_jobs=-1 
)

# Fit the model to find the best parameters
random_search.fit(X_train, y_train)

# Print the best parameters and score
print("Best Parameters:", random_search.best_params_)
# Out:
# D:\Anaconda - Data Science\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:12:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best Parameters: {'subsample': 1.0, 'scale_pos_weight': 20, 'reg_lambda': 0.1, 'reg_alpha': 0.5, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 5, 'learning_rate': 0.05, 'gamma': 0.1, 'colsample_bytree': 0.6}

# %%
xgb_model_tuned = XGBClassifier(use_label_encoder=False,
                                eval_metric='logloss',
                                random_state=42,
                                subsample=1.0,
                                scale_pos_weight=20,
                                reg_lambda=0.1,
                                reg_alpha=0.5, 
                                n_estimators=200,
                                min_child_weight=1,
                                max_depth=5,
                                learning_rate=0.05,
                                gamma=0.1, 
                                colsample_bytree=0.6)

results_xgb_tuned = xgb_model_tuned.fit(X_train, y_train)

y_pred_xgb_tuned = results_xgb_tuned.predict(X_test)
y_prob_xgb_tuned = results_xgb_tuned.predict_proba(X_test)[:, 1]
# Out:
# D:\Anaconda - Data Science\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:14:24] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %% [markdown]
# <a id='eval_tune_xgb'></a>
# ## 5.6.4. Model Evaluation(Tune model)

# %%
update_scorecard('XGBoost tuned model', y_test, y_pred_xgb_tuned, y_prob_xgb_tuned)
score_card
# Out:
#                                          Model  AUC Score  Precision Score  \
# 0                  Logistic_regression_initial   0.978726         0.977528
# 1                    Logistic_regression_tuned   0.980942         1.000000
# 2       Random Forest Classifier Initial Model   0.986316         1.000000
# 3         Random Forest Classifier Tuned Model   0.984266         1.000000
# 4       Decision Tree Classifier Initial Model   0.947368         0.956989
# 5         Decision Tree Classifier Tuned Model   0.956122         0.988636
# 6                            SVM initial Model   0.982161         1.000000
# 7                              SVM tuned model   0.984377         1.000000
# 8   Gradient Boosting Classifier initial model   0.992244         1.000000
# 9     Gradient Boosting Classifier tuned model   0.985485         1.000000
# 10                       XGBoost initial Model   0.989363         1.000000
# 11                         XGBoost tuned model   0.986593         0.988889
#
#     Recall Score  Accuracy Score  f1-score
# 0       0.915789        0.947368  0.945652
# 1       0.915789        0.957895  0.956044
# 2       0.936842        0.968421  0.967391
# 3       0.936842        0.968421  0.967391
# 4       0.936842        0.947368  0.946809
# 5       0.915789        0.952632  0.950820
# 6       0.884211        0.942105  0.938547
# 7       0.926316        0.963158  0.961749
# 8       0.936842        0.968421  0.967391
# 9       0.926316        0.963158  0.961749
# 10      0.926316        0.963158  0.961749
# 11      0.936842        0.963158  0.962162

# %% [markdown]
# <a id='ar_curve_tune_xgb'></a>
# ## 5.6.5 AUC ROC Curve(Tuned model)

# %%
# Predict probabilities for the test set
y_prob = xgb_model_tuned.predict_proba(X_test)[:, 1]  # Probability of positive class

# Calculate the AUC score
auc_score = roc_auc_score(y_test, y_prob)
print(f'AUC Score: {auc_score:.4f}')

# Compute the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# Plot the AUC-ROC curve
plt.figure(figsize=(8, 6))
sns.lineplot(x=fpr, y=tpr, label=f'AUC = {auc_score:.4f}', color='blue')
plt.plot([0, 1], [0, 1], linestyle='--', color='red')  # Dashed diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for XGBoost tuned model')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# AUC Score: 0.9866
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <a id='mode_val_xgb'></a>
# ## 5.6.6 Model Validation

# %%
# Perform cross-validation with the best model
cv_scores = cross_val_score(xgb_model_tuned, X_train, y_train, cv=5, scoring='roc_auc')

print("Cross-Validation AUC Scores:", cv_scores)
print("Mean AUC Score:", cv_scores.mean())
# Out:
# D:\Anaconda - Data Science\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:14:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# D:\Anaconda - Data Science\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:14:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# D:\Anaconda - Data Science\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:14:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# D:\Anaconda - Data Science\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:14:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# D:\Anaconda - Data Science\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:14:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Cross-Validation AUC Scores: [0.99186288 0.96333333 0.9954386  1.         0.99245614]
# Mean AUC Score: 0.9886181902123731

# %% [markdown]
# <a id='feat_imp_xgb'></a>
# ## 5.6.7 Feature Importance

# %%
# Get feature importance scores
importance = xgb_model_tuned.feature_importances_

# Create a DataFrame for better visualization
features = X_train.columns
importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': importance
}).sort_values(by='Importance', ascending=False)

# Plot feature importance
plt.figure(figsize=(10, 8))
plt.barh(importance_df['Feature'], importance_df['Importance'], color='teal')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.title('Feature Importance in XGBoost Classifier')
plt.gca().invert_yaxis()  # To display the most important features at the top
plt.show()

# %% [markdown]
# **features `V14,V12,V7` are making more influence in decision making, while features like `V16,V7,Time` are making less influence in decision making**

# %% [markdown]
# <a id='conf_mat_xgb'></a>
# ## 5.6.8 Confusion Matrix

# %%
# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred_xgb_tuned)

# Create a ConfusionMatrixDisplay object
disp = ConfusionMatrixDisplay(confusion_matrix=cm)

# Plot the confusion matrix
disp.plot(cmap='Blues')
plt.title('Confusion Matrix for XGBoost model')
plt.show()

# %% [markdown]
#     94(True Positives (TP)): The model correctly predicted 88 fraudulent transactions as fraudulent.
#     89(True Negatives (TN)): The model correctly predicted 94 non-fraudulent transactions as non-fraudulent.
#     6(False Positives (FP)): The model incorrectly predicted 1 non-fraudulent transaction as fraudulent.
#     1(False Negatives (FN)): The model incorrectly predicted 7 fraudulent transactions as non-fraudulent.

# %%
# Save the model using joblib
joblib.dump(xgb_model, 'C:/Users/dell/FINAL_CAPSTONE_PROJECT/find-default-prediction-of-credit-card-fraud)/models/xgb_model.joblib')
# Out:
# ['C:/Users/dell/FINAL_CAPSTONE_PROJECT/find-default-prediction-of-credit-card-fraud)/models/xgb_model.joblib']

# %% [markdown]
# # --------------------------------------------------------------------------------------

# %% [markdown]
# <a id='lgbm_model'></a>
# ## 5.7 LightGBM Model

# %%
from lightgbm import LGBMClassifier

# %%
# Initialize the model
lgbm_model = LGBMClassifier(random_state=42)

# Train the model
results_lgbm = lgbm_model.fit(X_train, y_train)

# Make predictions
y_pred_lgbm = results_lgbm.predict(X_test)
y_prob_lgbm = results_lgbm.predict_proba(X_test)[:, 1]
# Out:
# [LightGBM] [Info] Number of positive: 378, number of negative: 378
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001095 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5803
# [LightGBM] [Info] Number of data points in the train set: 756, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %% [markdown]
# <a id='eval_lgbm'></a>
# ## 5.7.1 Model evaluation

# %%
update_scorecard('LightGBM initial Model', y_test, y_pred_lgbm, y_prob_lgbm)
score_card
# Out:
#                                          Model  AUC Score  Precision Score  \
# 0                  Logistic_regression_initial   0.978726         0.977528
# 1                    Logistic_regression_tuned   0.980942         1.000000
# 2       Random Forest Classifier Initial Model   0.986316         1.000000
# 3         Random Forest Classifier Tuned Model   0.984266         1.000000
# 4       Decision Tree Classifier Initial Model   0.947368         0.956989
# 5         Decision Tree Classifier Tuned Model   0.956122         0.988636
# 6                            SVM initial Model   0.982161         1.000000
# 7                              SVM tuned model   0.984377         1.000000
# 8   Gradient Boosting Classifier initial model   0.992244         1.000000
# 9     Gradient Boosting Classifier tuned model   0.985485         1.000000
# 10                       XGBoost initial Model   0.989363         1.000000
# 11                         XGBoost tuned model   0.986593         0.988889
# 12                      LightGBM initial Model   0.987701         1.000000
#
#     Recall Score  Accuracy Score  f1-score
# 0       0.915789        0.947368  0.945652
# 1       0.915789        0.957895  0.956044
# 2       0.936842        0.968421  0.967391
# 3       0.936842        0.968421  0.967391
# 4       0.936842        0.947368  0.946809
# 5       0.915789        0.952632  0.950820
# 6       0.884211        0.942105  0.938547
# 7       0.926316        0.963158  0.961749
# 8       0.936842        0.968421  0.967391
# 9       0.926316        0.963158  0.961749
# 10      0.926316        0.963158  0.961749
# 11      0.936842        0.963158  0.962162
# 12      0.915789        0.957895  0.956044

# %% [markdown]
# <a id='ar_curve_lgbm'></a>
# ## 5.7.2 AUC ROC Curve

# %%
# Predict probabilities for the test set
y_prob = lgbm_model.predict_proba(X_test)[:, 1]  # Probability of positive class

# Calculate the AUC score
auc_score = roc_auc_score(y_test, y_prob)
print(f'AUC Score: {auc_score:.4f}')

# Compute the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# Plot the AUC-ROC curve
plt.figure(figsize=(8, 6))
sns.lineplot(x=fpr, y=tpr, label=f'AUC = {auc_score:.4f}', color='green')
plt.plot([0, 1], [0, 1], linestyle='--', color='red')  # Dashed diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for LightGBM initial model')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# AUC Score: 0.9877
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <a id='hyp_tune_lgbm'></a>
# ## 5.7.3 Hyperparameter Tuning

# %%
# Define the model
lgb_model = LGBMClassifier(random_state=42)

# Define the parameter grid for RandomizedSearchCV
param_grid = {
    'n_estimators': [100, 200, 500, 1000], 
    'learning_rate': [0.01, 0.05, 0.1, 0.2], 
    'max_depth': [3, 5, 7, 10, -1], 
    'num_leaves': [20, 31, 40, 50],  
    'min_child_samples': [5, 10, 20, 30],  
    'min_child_weight': [0.001, 0.01, 0.1, 1],  
    'subsample': [0.6, 0.8, 1.0],  
    'colsample_bytree': [0.6, 0.8, 1.0], 
    'reg_alpha': [0, 0.1, 0.5, 1],  
    'reg_lambda': [0, 0.1, 0.5, 1],  
    'scale_pos_weight': [1, 10, 20, 30] 
}

# %%
random_search = RandomizedSearchCV(
    estimator=lgb_model, 
    param_distributions=param_grid, 
    n_iter=50,  
    scoring='f1', 
    cv=5,  
    random_state=42, 
    n_jobs=-1 
)

# Fit the model to find the best parameters
random_search.fit(X_train, y_train)

# Print the best parameters and score
print("Best Parameters:", random_search.best_params_)
# Out:
# [LightGBM] [Info] Number of positive: 378, number of negative: 378
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000526 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5803
# [LightGBM] [Info] Number of data points in the train set: 756, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# ...
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# Best Parameters: {'subsample': 1.0, 'scale_pos_weight': 1, 'reg_lambda': 0.1, 'reg_alpha': 0.1, 'num_leaves': 31, 'n_estimators': 1000, 'min_child_weight': 0.001, 'min_child_samples': 5, 'max_depth': -1, 'learning_rate': 0.2, 'colsample_bytree': 0.8}

# %%
lgb_model_tuned = XGBClassifier(use_label_encoder=False,
                                eval_metric='logloss',
                                random_state=42,
                               subsample=1.0,
                               scale_pos_weight=1,
                               reg_lambda=0.1,
                               reg_alpha=0.1,
                               num_leaves=31,
                               n_estimators=100,
                               min_child_weight=0.01,
                               min_child_samples=10,
                               max_depth=5,
                               learning_rate=0.01,
                               colsample_bytree=0.6)

results_lgb_tuned = lgb_model_tuned.fit(X_train, y_train)

y_pred_lgb_tuned = results_lgb_tuned.predict(X_test)
y_prob_lgb_tuned = results_lgb_tuned.predict_proba(X_test)[:, 1]
# Out:
# D:\Anaconda - Data Science\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:22:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "min_child_samples", "num_leaves", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %% [markdown]
# <a id='eval_tune_lgbm'></a>
# ## 5.7.4. Model Evaluation(Tune model)

# %%
update_scorecard('LightGBM tuned model', y_test, y_pred_lgb_tuned, y_prob_lgb_tuned)
score_card
# Out:
#                                          Model  AUC Score  Precision Score  \
# 0                  Logistic_regression_initial   0.978726         0.977528
# 1                    Logistic_regression_tuned   0.980942         1.000000
# 2       Random Forest Classifier Initial Model   0.986316         1.000000
# 3         Random Forest Classifier Tuned Model   0.984266         1.000000
# 4       Decision Tree Classifier Initial Model   0.947368         0.956989
# 5         Decision Tree Classifier Tuned Model   0.956122         0.988636
# 6                            SVM initial Model   0.982161         1.000000
# 7                              SVM tuned model   0.984377         1.000000
# 8   Gradient Boosting Classifier initial model   0.992244         1.000000
# 9     Gradient Boosting Classifier tuned model   0.985485         1.000000
# 10                       XGBoost initial Model   0.989363         1.000000
# 11                         XGBoost tuned model   0.986593         0.988889
# 12                      LightGBM initial Model   0.987701         1.000000
# 13                        LightGBM tuned model   0.983657         1.000000
#
#     Recall Score  Accuracy Score  f1-score
# 0       0.915789        0.947368  0.945652
# 1       0.915789        0.957895  0.956044
# 2       0.936842        0.968421  0.967391
# 3       0.936842        0.968421  0.967391
# 4       0.936842        0.947368  0.946809
# 5       0.915789        0.952632  0.950820
# 6       0.884211        0.942105  0.938547
# 7       0.926316        0.963158  0.961749
# 8       0.936842        0.968421  0.967391
# 9       0.926316        0.963158  0.961749
# 10      0.926316        0.963158  0.961749
# 11      0.936842        0.963158  0.962162
# 12      0.915789        0.957895  0.956044
# 13      0.905263        0.952632  0.950276

# %% [markdown]
# <a id='ar_curve_tune_lgbm'></a>
# ## 5.7.5 AUC ROC Curve(Tuned model)

# %%
# Predict probabilities for the test set
y_prob = lgb_model_tuned.predict_proba(X_test)[:, 1]  # Probability of positive class

# Calculate the AUC score
auc_score = roc_auc_score(y_test, y_prob)
print(f'AUC Score: {auc_score:.4f}')

# Compute the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# Plot the AUC-ROC curve
plt.figure(figsize=(8, 6))
sns.lineplot(x=fpr, y=tpr, label=f'AUC = {auc_score:.4f}', color='green')
plt.plot([0, 1], [0, 1], linestyle='--', color='red')  # Dashed diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for LightGBM tuned model')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# AUC Score: 0.9837
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda - Data Science\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <a id='mode_val_lgbm'></a>
# ## 5.7.6 Model Validation

# %%
# Perform cross-validation with the best model
cv_scores = cross_val_score(lgbm_model, X_train, y_train, cv=5, scoring='roc_auc')

print("Cross-Validation AUC Scores:", cv_scores)
print("Mean AUC Score:", cv_scores.mean())
# Out:
# [LightGBM] [Info] Number of positive: 302, number of negative: 302
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000400 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4636
# [LightGBM] [Info] Number of data points in the train set: 604, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 303, number of negative: 302
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000347 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4644
# [LightGBM] [Info] Number of data points in the train set: 605, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500826 -> initscore=0.003306
# [LightGBM] [Info] Start training from score 0.003306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 303, number of negative: 302
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000152 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4645
# [LightGBM] [Info] Number of data points in the train set: 605, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500826 -> initscore=0.003306
# [LightGBM] [Info] Start training from score 0.003306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 302, number of negative: 303
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000309 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4645
# [LightGBM] [Info] Number of data points in the train set: 605, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499174 -> initscore=-0.003306
# [LightGBM] [Info] Start training from score -0.003306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 302, number of negative: 303
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000347 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4645
# [LightGBM] [Info] Number of data points in the train set: 605, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499174 -> initscore=-0.003306
# [LightGBM] [Info] Start training from score -0.003306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Cross-Validation AUC Scores: [0.99359418 0.96210526 0.99122807 0.99964912 0.9922807 ]
# Mean AUC Score: 0.9877714681440443

# %% [markdown]
# <a id='feat_imp_lgbm'></a>
# ## 5.7.7 Feature Importance

# %%
# Get feature importance scores
importance = lgbm_model.feature_importances_

# Create a DataFrame for better visualization
features = X_train.columns
importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': importance
}).sort_values(by='Importance', ascending=False)

# Plot feature importance
plt.figure(figsize=(10, 8))
plt.barh(importance_df['Feature'], importance_df['Importance'], color='teal')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.title('Feature Importance in LightGBM Classifier')
plt.gca().invert_yaxis()  # To display the most important features at the top
plt.show()

# %% [markdown]
# **features `V14,V4,Amount` are making more influence in decision making, while features like `V9,V27,V18` are making less influence in decision making**

# %% [markdown]
# <a id='conf_mat_lgbm'></a>
# ## 5.7.8 Confusion Matrix

# %%
# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred_lgbm)

# Create a ConfusionMatrixDisplay object
disp = ConfusionMatrixDisplay(confusion_matrix=cm)

# Plot the confusion matrix
disp.plot(cmap='Blues')
plt.title('Confusion Matrix for LightGBM model')
plt.show()

# %% [markdown]
#     95(True Positives (TP)): The model correctly predicted 87 fraudulent transactions as fraudulent.
#     87(True Negatives (TN)): The model correctly predicted 95 non-fraudulent transactions as non-fraudulent.
#     8(False Positives (FP)): The model incorrectly predicted 0 non-fraudulent transaction as fraudulent.
#     0(False Negatives (FN)): The model incorrectly predicted 8 fraudulent transactions as non-fraudulent.

# %%
# Save the model using joblib
joblib.dump(lgbm_model, 'C:/Users/dell/FINAL_CAPSTONE_PROJECT/find-default-prediction-of-credit-card-fraud)/models/lgb_model.joblib')
# Out:
# ['C:/Users/dell/FINAL_CAPSTONE_PROJECT/find-default-prediction-of-credit-card-fraud)/models/lgb_model.joblib']

# %% [markdown]
# <a id='final_score'></a>
# # 6. FINAL SCORE CARD

# %%
score_card.style.highlight_max(subset=['Accuracy Score','AUC Score','Precision Score','Recall Score','f1-score'], color='green')
# Out:
# <style type="text/css">
# #T_abee2_row1_col2, #T_abee2_row2_col2, #T_abee2_row2_col3, #T_abee2_row2_col4, #T_abee2_row2_col5, #T_abee2_row3_col2, #T_abee2_row3_col3, #T_abee2_row3_col4, #T_abee2_row3_col5, #T_abee2_row4_col3, #T_abee2_row6_col2, #T_abee2_row7_col2, #T_abee2_row8_col1, #T_abee2_row8_col2, #T_abee2_row8_col3, #T_abee2_row8_col4, #T_abee2_row8_col5, #T_abee2_row9_col2, #T_abee2_row10_col2, #T_abee2_row11_col3, #T_abee2_row12_col2, #T_abee2_row13_col2 {
#   background-color: green;
# }
# </style>
# <table id="T_abee2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_abee2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_abee2_level0_col1" class="col_heading level0 col1" >AUC Score</th>
#       <th id="T_abee2_level0_col2" class="col_heading level0 col2" >Precision Score</th>
#       <th id="T_abee2_level0_col3" class="col_heading level0 col3" >Recall Score</th>
#       <th id="T_abee2_level0_col4" class="col_heading level0 col4" >Accuracy Score</th>
#       <th id="T_abee2_level0_col5" class="col_heading level0 col5" >f1-score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_abee2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_abee2_row0_col0" class="data row0 col0" >Logistic_regression_initial</td>
#       <td id="T_abee2_row0_col1" class="data row0 col1" >0.978726</td>
#       <td id="T_abee2_row0_col2" class="data row0 col2" >0.977528</td>
#       <td id="T_abee2_row0_col3" class="data row0 col3" >0.915789</td>
#       <td id="T_abee2_row0_col4" class="data row0 col4" >0.947368</td>
#       <td id="T_abee2_row0_col5" class="data row0 col5" >0.945652</td>
#     </tr>
#     <tr>
#       <th id="T_abee2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_abee2_row1_col0" class="data row1 col0" >Logistic_regression_tuned</td>
#       <td id="T_abee2_row1_col1" class="data row1 col1" >0.980942</td>
#       <td id="T_abee2_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_abee2_row1_col3" class="data row1 col3" >0.915789</td>
#       <td id="T_abee2_row1_col4" class="data row1 col4" >0.957895</td>
#       <td id="T_abee2_row1_col5" class="data row1 col5" >0.956044</td>
#     </tr>
#     <tr>
#       <th id="T_abee2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_abee2_row2_col0" class="data row2 col0" >Random Forest Classifier Initial Model</td>
#       <td id="T_abee2_row2_col1" class="data row2 col1" >0.986316</td>
#       <td id="T_abee2_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_abee2_row2_col3" class="data row2 col3" >0.936842</td>
#       <td id="T_abee2_row2_col4" class="data row2 col4" >0.968421</td>
#       <td id="T_abee2_row2_col5" class="data row2 col5" >0.967391</td>
#     </tr>
#     <tr>
#       <th id="T_abee2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_abee2_row3_col0" class="data row3 col0" >Random Forest Classifier Tuned Model</td>
#       <td id="T_abee2_row3_col1" class="data row3 col1" >0.984266</td>
#       <td id="T_abee2_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_abee2_row3_col3" class="data row3 col3" >0.936842</td>
#       <td id="T_abee2_row3_col4" class="data row3 col4" >0.968421</td>
#       <td id="T_abee2_row3_col5" class="data row3 col5" >0.967391</td>
#     </tr>
#     <tr>
#       <th id="T_abee2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_abee2_row4_col0" class="data row4 col0" >Decision Tree Classifier Initial Model</td>
#       <td id="T_abee2_row4_col1" class="data row4 col1" >0.947368</td>
#       <td id="T_abee2_row4_col2" class="data row4 col2" >0.956989</td>
#       <td id="T_abee2_row4_col3" class="data row4 col3" >0.936842</td>
#       <td id="T_abee2_row4_col4" class="data row4 col4" >0.947368</td>
#       <td id="T_abee2_row4_col5" class="data row4 col5" >0.946809</td>
#     </tr>
#     <tr>
#       <th id="T_abee2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_abee2_row5_col0" class="data row5 col0" >Decision Tree Classifier Tuned Model</td>
#       <td id="T_abee2_row5_col1" class="data row5 col1" >0.956122</td>
#       <td id="T_abee2_row5_col2" class="data row5 col2" >0.988636</td>
#       <td id="T_abee2_row5_col3" class="data row5 col3" >0.915789</td>
#       <td id="T_abee2_row5_col4" class="data row5 col4" >0.952632</td>
#       <td id="T_abee2_row5_col5" class="data row5 col5" >0.950820</td>
#     </tr>
#     <tr>
#       <th id="T_abee2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_abee2_row6_col0" class="data row6 col0" >SVM initial Model</td>
#       <td id="T_abee2_row6_col1" class="data row6 col1" >0.982161</td>
#       <td id="T_abee2_row6_col2" class="data row6 col2" >1.000000</td>
#       <td id="T_abee2_row6_col3" class="data row6 col3" >0.884211</td>
#       <td id="T_abee2_row6_col4" class="data row6 col4" >0.942105</td>
#       <td id="T_abee2_row6_col5" class="data row6 col5" >0.938547</td>
#     </tr>
#     <tr>
#       <th id="T_abee2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_abee2_row7_col0" class="data row7 col0" >SVM tuned model</td>
#       <td id="T_abee2_row7_col1" class="data row7 col1" >0.984377</td>
#       <td id="T_abee2_row7_col2" class="data row7 col2" >1.000000</td>
#       <td id="T_abee2_row7_col3" class="data row7 col3" >0.926316</td>
#       <td id="T_abee2_row7_col4" class="data row7 col4" >0.963158</td>
#       <td id="T_abee2_row7_col5" class="data row7 col5" >0.961749</td>
#     </tr>
#     <tr>
#       <th id="T_abee2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_abee2_row8_col0" class="data row8 col0" >Gradient Boosting Classifier initial model</td>
#       <td id="T_abee2_row8_col1" class="data row8 col1" >0.992244</td>
#       <td id="T_abee2_row8_col2" class="data row8 col2" >1.000000</td>
#       <td id="T_abee2_row8_col3" class="data row8 col3" >0.936842</td>
#       <td id="T_abee2_row8_col4" class="data row8 col4" >0.968421</td>
#       <td id="T_abee2_row8_col5" class="data row8 col5" >0.967391</td>
#     </tr>
#     <tr>
#       <th id="T_abee2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_abee2_row9_col0" class="data row9 col0" >Gradient Boosting Classifier tuned model</td>
#       <td id="T_abee2_row9_col1" class="data row9 col1" >0.985485</td>
#       <td id="T_abee2_row9_col2" class="data row9 col2" >1.000000</td>
#       <td id="T_abee2_row9_col3" class="data row9 col3" >0.926316</td>
#       <td id="T_abee2_row9_col4" class="data row9 col4" >0.963158</td>
#       <td id="T_abee2_row9_col5" class="data row9 col5" >0.961749</td>
#     </tr>
#     <tr>
#       <th id="T_abee2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_abee2_row10_col0" class="data row10 col0" >XGBoost initial Model</td>
#       <td id="T_abee2_row10_col1" class="data row10 col1" >0.989363</td>
#       <td id="T_abee2_row10_col2" class="data row10 col2" >1.000000</td>
#       <td id="T_abee2_row10_col3" class="data row10 col3" >0.926316</td>
#       <td id="T_abee2_row10_col4" class="data row10 col4" >0.963158</td>
#       <td id="T_abee2_row10_col5" class="data row10 col5" >0.961749</td>
#     </tr>
#     <tr>
#       <th id="T_abee2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_abee2_row11_col0" class="data row11 col0" >XGBoost tuned model</td>
#       <td id="T_abee2_row11_col1" class="data row11 col1" >0.986593</td>
#       <td id="T_abee2_row11_col2" class="data row11 col2" >0.988889</td>
#       <td id="T_abee2_row11_col3" class="data row11 col3" >0.936842</td>
#       <td id="T_abee2_row11_col4" class="data row11 col4" >0.963158</td>
#       <td id="T_abee2_row11_col5" class="data row11 col5" >0.962162</td>
#     </tr>
#     <tr>
#       <th id="T_abee2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_abee2_row12_col0" class="data row12 col0" >LightGBM initial Model</td>
#       <td id="T_abee2_row12_col1" class="data row12 col1" >0.987701</td>
#       <td id="T_abee2_row12_col2" class="data row12 col2" >1.000000</td>
#       <td id="T_abee2_r

# %% [markdown]
# ## Business Insights
#
# For banks with smaller average transaction value, we would want high precision because we only want to label relevant transactions as fraudulent. For every transaction that is flagged as fraudulent, we can add the human element to verify whether the transaction was done by calling the customer. However, when precision is low, such tasks are a burden because the human element has to be increased.
#
# For banks having a larger transaction value, if the recall is low, i.e., it is unable to detect transactions that are labelled as non-fraudulent. So we have to consider the losses if the missed transaction was a high-value fraudulent one.
#
# So here, to save the banks from high-value fraudulent transactions, we have to focus on a high recall in order to detect actual fraudulent transactions.
#
# After performing several models, we have seen that in the balanced dataset with SMOTE technique the simplest Logistic regression model has good ROC score and also high Recall. Hence, we can go with the logistic model here. It is also easier to interpret and explain to the business.
